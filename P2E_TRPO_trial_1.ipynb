# %% [markdown]
# # **P2E - TRPO**
#
# Integrating Trust to learn whats unknown, fist trial to break AI limits

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import numpy as np

from collections import deque
import warnings

import gymnasium as gym
from gymnasium.wrappers import RescaleAction

import copy

# %%
warnings.filterwarnings(action = 'ignore', category = UserWarning)

# %% [markdown]
# ## **Env Setup**

# %%
env = gym.make('Humanoid-v5')

env = RescaleAction(env, min_action = -1.0, max_action = 1.0)

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = env.action_space.high[0]

print(f'State dim: {state_dim} | Action dim: {action_dim} | Max Action: {max_action}')
# Out:
# State dim: 348 | Action dim: 17 | Max Action: 1.0

# %% [markdown]
# ### **Device Setup**

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(f'Device using: {device}')
# Out:
# Device using: cuda

# %% [markdown]
# ## **Encoder**
#
# converting raw states to latent space

# %%
class Encoder(nn.Module):
    
    def __init__(self, input_dim, latent_dim, head_1, head_2, head_3, head_4):
        super(Encoder, self).__init__()
        
        self.encoder = nn.Sequential(
            
            
            nn.Linear(input_dim, head_1),
            nn.SiLU(),
            
            nn.Linear(head_1, head_2),
            nn.SiLU(),
            
            nn.Linear(head_2, head_3),
            nn.SiLU(),
            
            nn.Linear(head_3, head_4),
            nn.SiLU(),
            
            nn.Linear(head_4, latent_dim)
        )
        
    def forward(self, x):
        
        return self.encoder(x)

# %% [markdown]
# ## **GRU Based World Model**

# %%
class GRU_World_MODEL(nn.Module):
    
    def __init__(self, latent_dim, action_dim, head_1, head_2, head_3, head_4):
        super(GRU_World_MODEL, self).__init__()
        
        self.gru = nn.GRU(latent_dim + action_dim, head_1, num_layers = 4, batch_first = True)
        
        self.norm = nn.LayerNorm(head_1)
        
        self.extract = nn.Sequential(
            
            nn.Linear(head_1, head_2),
            nn.SiLU(),
            
            nn.Linear(head_2, head_3),
            nn.SiLU(),
            
            nn.Linear(head_3, head_4),
            nn.SiLU(),
            
            nn.Linear(head_4, latent_dim)
        )
        
        self.head_1 = head_1
        
    def forward(self, latent_state, action, h = None):
        
        x = torch.cat([latent_state, action], dim = -1)
        
        batch_size = x.size(0)

        if h is None:
            
            h = torch.zeros(4, batch_size, self.head_1, device = device)        
            
        x = x.unsqueeze(1)
            
        gru_out, h_out = self.gru(x, h)
        
        gru_out = gru_out.squeeze(1)
        
        norm = self.norm(gru_out)
        
        predicted_states = self.extract(norm)
        
        return predicted_states, h_out

# %% [markdown]
# ## **Ensemble World Models**

# %%
def init_weights(m):
    
    if isinstance(m, nn.Linear):
        
        nn.init.kaiming_normal_(m.weight)
        
        if m.bias is not None:
            
            nn.init.zeros_(m.bias)

# %%
class ENSEMBLE(nn.Module):
    
    def __init__(self, world_model, ensemble_size):
        super(ENSEMBLE, self).__init__()
        
        self.models = nn.ModuleList(
            
            [copy.deepcopy(world_model) for _ in range(ensemble_size)]
        )
        
        for model in self.models:
            
            model.apply(init_weights)
            
            for param in model.parameters():
                
                param.data += 0.01 * torch.randn_like(param)
                
    def forward(self, latent_state, action, h = None):
        
        preds , hidden_states = [], []
        
        if isinstance(action, np.ndarray):
            
            action = torch.tensor(action, dtype = torch.float32, device = latent_state.device)
            
        if action.dim() == 1:
            
            action = action.unsqueeze(0)
        
        for model in self.models:
            
            pred, h_out = model(latent_state, action)
            
            preds.append(pred)
            hidden_states.append(h_out)
            
        return torch.stack(preds, dim = 0) , torch.stack(hidden_states, dim = 0)

# %% [markdown]
# ### **Setup**

# %%
# Assembly

head_1 = 256
head_2 = 512
head_3 = 512
head_4 = 256

latent_dim = 256

ensemble_size = 5

# Encoder setup

encoder = Encoder(state_dim, latent_dim, head_1, head_2, head_3, head_4).to(device)

# GRU World model

world_model = GRU_World_MODEL(latent_dim, action_dim, head_1, head_2, head_3, head_4).to(device)

# Ensemble

ensemble = ENSEMBLE(world_model, ensemble_size).to(device)

print("-" * 70)

print(encoder)

print("-" * 70)

print(world_model)

print('-' * 70)

print(ensemble)
# Out:
# ----------------------------------------------------------------------
# Encoder(
#   (encoder): Sequential(
#     (0): Linear(in_features=348, out_features=256, bias=True)
#     (1): SiLU()
#     (2): Linear(in_features=256, out_features=512, bias=True)
#     (3): SiLU()
#     (4): Linear(in_features=512, out_features=512, bias=True)
#     (5): SiLU()
#     (6): Linear(in_features=512, out_features=256, bias=True)
#     (7): SiLU()
#     (8): Linear(in_features=256, out_features=256, bias=True)
#   )
# )
# ----------------------------------------------------------------------
# GRU_World_MODEL(
#   (gru): GRU(273, 256, num_layers=4, batch_first=True)
#   (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   (extract): Sequential(
#     (0): Linear(in_features=256, out_features=512, bias=True)
#     (1): SiLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): SiLU()
#     (4): Linear(in_features=512, out_features=256, bias=True)
#     (5): SiLU()
#     (6): Linear(in_features=256, out_features=256, bias=True)
#   )
# )
# ----------------------------------------------------------------------
# ENSEMBLE(
#   (models): ModuleList(
#     (0-4): 5 x GRU_World_MODEL(
#       (gru): GRU(273, 256, num_layers=4, batch_first=True)
#       (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (extract): Sequential(
#         (0): Linear(in_features=256, out_features=512, bias=True)
#         (1): SiLU()
#         (2): Linear(in_features=512, out_features=512, bias=True)
#         (3): SiLU()
#         (4): Linear(in_features=512, out_features=256, bias=True)
#         (5): SiLU()
#         (6): Linear(in_features=256, out_features=256, bias=True)
#       )
#     )
#   )
# )

# %% [markdown]
# ## **TRPO NETWORK**

# %%
class Feature_Extractor(nn.Module):
    
    def __init__(self, input_dim, output_dim, hidden_size, hidden_size_2):
        super(Feature_Extractor, self).__init__()
        
        self.feature = nn.Sequential(
            
            nn.Linear(input_dim, hidden_size),
            nn.SiLU(),
            
            nn.Linear(hidden_size, hidden_size),
            nn.SiLU(),
            
            
            nn.Linear(hidden_size, hidden_size),
            nn.SiLU(),
            
            nn.LayerNorm(hidden_size),
            nn.Linear(hidden_size, hidden_size_2),
            nn.SiLU(),
            
            nn.Linear(hidden_size_2, hidden_size_2),
            nn.SiLU(),
            
            
            nn.Linear(hidden_size_2, output_dim),
            nn.SiLU()
        )
        
    def forward(self, x):
        
        return self.feature(x)

# %%
class Policy_Network(nn.Module):
    
    def __init__(self, latent_dim, action_dim, head_1, head_2, head_3, head_4, hidden_size, hidden_size_2, max_action = max_action):
        super(Policy_Network, self).__init__()
        
        self.max_action = max_action
        
        self.feature = Feature_Extractor(latent_dim, head_1, hidden_size, hidden_size_2)
        
        self.policy = nn.Sequential(
            
            nn.Linear(head_1, head_2),
            nn.SiLU(),
            
            nn.LayerNorm(head_2),
            nn.Linear(head_2, head_3),
            nn.SiLU(),
            
            nn.Linear(head_3, head_4),
            nn.SiLU()
        )
        
        self.mu = nn.Linear(head_4, action_dim)
        self.log_std = nn.Linear(head_4, action_dim)
        
    def forward(self, latent_state):
        
        x = self.feature(latent_state)
        
        policy = self.policy(x)
        
        mu = self.mu(policy)
        log_std = self.log_std(policy)
        
        mu = torch.tanh_(mu)             # Range [-1.0, 1.0]
        log_std = torch.tanh_(log_std)
        
        log_std = log_std.clamp(min = -10, max = 2)
        std = torch.exp(log_std)
        
        dist = torch.distributions.Normal(mu, std)
        z = dist.rsample()
        tanh_z = torch.tanh_(z)
        log_prob = dist.log_prob(z)
        action = tanh_z * self.max_action

        # Squashing
        
        squash = 2 * (torch.log(torch.tensor(2.0, device=z.device)) - z - F.softplus(-2 * z))        
        log_prob = log_prob - squash
        log_prob = torch.sum(log_prob, dim = -1, keepdim = True)
        
        return action, log_prob, mu, log_std

# %% [markdown]
# ### **Value Network**

# %%
class Value_Network(nn.Module):
    
    def __init__(self, latent_dim, head_1, head_2, head_3, head_4, hidden_size, hidden_size_2):
        super(Value_Network, self).__init__()
        
        self.feature = Feature_Extractor(latent_dim, head_1, hidden_size, hidden_size_2)
        
        self.norm = nn.LayerNorm(head_1)
        
        self.values = nn.Sequential(
            
            nn.Linear(head_1, head_2),
            nn.SiLU(),
            
            nn.LayerNorm(head_2),
            nn.Linear(head_2, head_3),
            nn.SiLU(),
            
            nn.Linear(head_3, head_4),
            nn.SiLU(),
            
            nn.Linear(head_4, 1)
        )
        
    def forward(self, latent_state):
        
        feature = self.feature(latent_state)
        
        norm = self.norm(feature)
        
        values = self.values(norm)
                
        return values

# %% [markdown]
# ### **Setup**

# %%
# Assembly

hidden_size = 256
hidden_size_2 = 512

lr = 2.5e-4
T_max = 3000

# Policy network

policy_network = Policy_Network(latent_dim, action_dim, head_1, head_2, head_3, head_4, hidden_size, hidden_size_2).to(device)

print('-' * 70)

print(policy_network)

# Value network

value_network = Value_Network(latent_dim, head_1, head_2, head_3, head_4, hidden_size, hidden_size_2).to(device)

print('-' * 70)

print(value_network)

# Value opt and Sch

value_optimizer = optim.AdamW(value_network.parameters(), lr, weight_decay = 0.001)
value_scheduler = optim.lr_scheduler.CosineAnnealingLR(value_optimizer, T_max)
# Out:
# ----------------------------------------------------------------------
# Policy_Network(
#   (feature): Feature_Extractor(
#     (feature): Sequential(
#       (0): Linear(in_features=256, out_features=256, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): SiLU()
#       (4): Linear(in_features=256, out_features=256, bias=True)
#       (5): SiLU()
#       (6): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (7): Linear(in_features=256, out_features=512, bias=True)
#       (8): SiLU()
#       (9): Linear(in_features=512, out_features=512, bias=True)
#       (10): SiLU()
#       (11): Linear(in_features=512, out_features=256, bias=True)
#       (12): SiLU()
#     )
#   )
#   (policy): Sequential(
#     (0): Linear(in_features=256, out_features=512, bias=True)
#     (1): SiLU()
#     (2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): SiLU()
#     (5): Linear(in_features=512, out_features=256, bias=True)
#     (6): SiLU()
#   )
#   (mu): Linear(in_features=256, out_features=17, bias=True)
#   (log_std): Linear(in_features=256, out_features=17, bias=True)
# )
# ----------------------------------------------------------------------
# Value_Network(
#   (feature): Feature_Extractor(
#     (feature): Sequential(
#       (0): Linear(in_features=256, out_features=256, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): SiLU()
#       (4): Linear(in_features=256, out_features=256, bias=True)
#       (5): SiLU()
#       (6): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (7): Linear(in_features=256, out_features=512, bias=True)
#       (8): SiLU()
#       (9): Linear(in_features=512, out_features=512, bias=True)
#       (10): SiLU()
#       (11): Linear(in_features=512, out_features=256, bias=True)
#       (12): SiLU()
#     )
#   )
#   (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   (values): Sequential(
#     (0): Linear(in_features=256, out_features=512, bias=True)
#     (1): SiLU()
#     (2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): SiLU()
#     (5): Linear(in_features=512, out_features=256, bias=True)
#     (6): SiLU()
#     (7): Linear(in_features=256, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ## **Intrinsic Reward Signal**

# %%
def intrinsic_reward_signal(ensemble, latent_states, actions, extrinsic_reward, beta, intrinsic_scale = 10.0):
    
    preds, h_out = ensemble(latent_states, actions)
    
    if preds.dim() == 3:
        
        preds = preds.permute(1, 0, 2)                                         # Shape [batch, ensemble_size, latent]
    
        Variance = torch.var(preds, dim = 1, keepdim = True)
        
        intrinsic_reward = torch.sum(Variance, dim = 1, keepdim = True)
        
    
    else:
        
        Variance = torch.var(preds, dim = 0, keepdim = True)
        
        intrinsic_reward = torch.sum(Variance, dim = 0, keepdim = True)
        
    intrinsic_reward = intrinsic_reward / (intrinsic_reward.std() + 1e-8)


    #intrinsic_reward = intrinsic_reward / intrinsic_scale
    intrinsic_reward = intrinsic_reward + beta * extrinsic_reward
    
    return intrinsic_reward.squeeze()

# %% [markdown]
# ## *World replay Buffer*

# %%
class OG_Replay_buffer:
    
    def __init__(self, capacity):
        
        
        self.capacity = capacity
        self.pos = 0
        self.buffer = deque(maxlen = capacity)
        self.roller_buffer = []
        
    def add(self, latent_state, action, reward, latent_next_state, done):
        
        # Safe conversion
        
        latent_state = torch.tensor(latent_state, dtype = torch.float32, device = device)
        action = torch.tensor(action, dtype = torch.float32, device = device)
        reward = torch.tensor(reward, dtype = torch.float32, device = device)
        latent_next_state = torch.tensor(latent_next_state, dtype = torch.float32, device = device)
        done = torch.tensor(done, dtype = torch.float32, device = device)
        
        # Add to buffer
        
        experience = (latent_state, action, reward, latent_next_state, done)
        
        if len(self.buffer) < self.capacity:
            
            self.buffer.append(experience)
            
        else:
            
            self.buffer[self.pos] = experience
            self.pos = (1 + self.pos) % self.capacity
            
    def sample(self, batch_size):
        
        if len(self.buffer) < batch_size:
            raise ValueError("Not enough samples in World Buffer.")
        
        indices = np.random.choice(len(self.buffer), batch_size)
        
        latent_states, actions, rewards, latent_next_states, dones = zip(*[self.buffer[ind] for ind in indices])
        
        # Stack these
        
        latent_states = torch.stack(latent_states).to(device)
        actions = torch.stack(actions).to(device)
        rewards = torch.stack(rewards).to(device)
        latent_next_states = torch.stack(latent_next_states).to(device)
        dones = torch.stack(dones).to(device)
        
        return (latent_states, actions, rewards, latent_next_states, dones)
    
    def add_rollout_data(self, state, action, reward, next_state, done, value):
        
        self.roller_buffer.append({
            
            'states': state.detach(),
            'actions': action.detach(),
            'rewards': reward.detach(),
            'next_states': next_state.detach(),
            'dones': done.detach(),
            'values': value.detach()
        })
        
    def sample_rollout(self, batch_size):
        
        indices = np.random.choice(len(self.roller_buffer), batch_size)
        
        samples = [self.roller_buffer[ind] for ind in indices]
        
        # Stack all trajectories
        
        def safe_cat(key):
            items = []
            for s in samples:
                val = s[key]
                if isinstance(val, np.ndarray):
                    val = torch.tensor(val, dtype=torch.float32, device=device)
                elif isinstance(val, list):
                    val = torch.tensor(val, dtype=torch.float32, device=device)
                if not isinstance(val, torch.Tensor):
                    val = torch.tensor(val, dtype=torch.float32, device=device)
                if val.ndim == 1:
                    val = val.unsqueeze(0)
                items.append(val)
            return torch.cat(items, dim=0)

        return {
            'states': safe_cat('states'),
            'actions': safe_cat('actions'),
            'rewards': safe_cat('rewards'),
            'next_states': safe_cat('next_states'),
            'dones': safe_cat('dones')
        }
        
    def mix_batch(self, batch_size, ratio):
        
        real_size = int(batch_size * ratio)
        batch_now = batch_size - real_size
        
        world_batch = self.sample(real_size)
        trpo_batch = self.sample_rollout(batch_now)
        
        # Now unzipping both 
        
        w_s, w_a, w_r, w_ns, w_d = world_batch
        
        t_s = trpo_batch['states']
        t_a = trpo_batch['actions']
        t_r = trpo_batch['rewards']
        t_ns = trpo_batch['next_states']
        t_d = trpo_batch['dones']
        
        # Shaping
        
        w_s = w_s.squeeze(1)
        w_ns = w_ns.squeeze(1)
        w_a = w_a.squeeze(1)
        
        w_r = w_r.mean(dim = 1, keepdim = True)
        
        # Concat them
        
        states = torch.cat([w_s, t_s], dim = 0).to(device)
        actions = torch.cat([w_a, t_a], dim = 0).to(device)
        rewards = torch.cat([w_r, t_r], dim = 0).to(device)
        next_states = torch.cat([w_ns, t_ns], dim = 0).to(device)
        dones = torch.cat([w_d, t_d], dim = 0).to(device)
        
        return states, actions, rewards, next_states, dones

# %% [markdown]
# ### **Setup**

# %%
# Hyper params

capacity = 500_000

batch_size = 256

# Setup

world_buffer = OG_Replay_buffer(capacity)

# %% [markdown]
# ## **World_loss_Function**

# %%
class WORLD_LOSS_FUNCTION:
    
    def __init__(self, world_model, world_optimizer, world_scheduler, encoder):
        
        self.model = world_model
        self.world_optimizer = world_optimizer
        self.world_scheduler = world_scheduler
        self.encoder = encoder
        
    def compute_loss(self, trajectories):
        
        states = trajectories['states'].to(device)
        actions = trajectories['actions'].to(device)
        next_states = trajectories['next_states'].to(device)
        
        # Babe here we need to check if states and next states are in latent space
        
        # If not
        if states.shape[-1] != self.encoder.encoder[-1].out_features:
            states = self.encoder(states)
            next_states = self.encoder(next_states)
        
        pred_latent_next_states, h_out = self.model(states, actions)
        
        loss = F.mse_loss(next_states, pred_latent_next_states)
        
        self.world_optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm = 1.0)
        self.world_optimizer.step()
        self.world_scheduler.step()
        
        return loss.item()

# %% [markdown]
# ### **Setup**

# %%
# Optimizer and Scheduler

world_optimizer = optim.AdamW(world_model.parameters(), lr, weight_decay = 0.001)
world_scheduler = optim.lr_scheduler.CosineAnnealingLR(world_optimizer, T_max)

# Setup

world_loss_function = WORLD_LOSS_FUNCTION(world_model, world_optimizer, world_scheduler, encoder)

# %% [markdown]
# ### **TRPO LOSS FUNCTION**

# %%
class TRPO_LOSS_FUNCTION:
    
    def __init__(self, policy_network, value_network, value_optimizer, value_scheduler, entropy_coef, max_iter, tolerance, damping, max_back_tracks, max_kl):
        
        # Network
        
        self.policy_network = policy_network
        self.value_network = value_network
        
        # optimizer and Scheduler
        
        self.value_opt = value_optimizer
        self.value_sch = value_scheduler
        
        # Hyper params
        
        self.max_kl = max_kl
        self.max_back_tracks = max_back_tracks
        self.entropy_coef = entropy_coef
        self.max_iter = max_iter
        self.tolerance = tolerance
        self.damping = damping
        
        
    def compute_gae(self, rewards, last_value, values, dones, gamma, gae_lambda):
                
        gae = 0
        advantages = []
                
        values = torch.tensor(values.tolist() + [last_value], dtype = torch.float32, device = device)
        rewards = torch.tensor(rewards, dtype = torch.float32, device = device)
        dones = torch.tensor(dones, dtype = torch.float32, device = device)
                
        for step in reversed(range(len(rewards))):
                    
            delta_gae = rewards[step] + gamma * (1 - dones[step]) * values[step + 1] - values[step]
            gae = delta_gae + gamma * gae * gae_lambda
                    
            advantages.append(gae)
                    
        advantages = advantages[::-1]
                
        returns = [adv + val for adv, val in zip(advantages, values)]
                
        advantages = torch.tensor(advantages, dtype = torch.float32, device = device)
        returns = torch.tensor(returns, dtype = torch.float32, device = device)
                
        return advantages, returns
        
    def safe_tensor(self, x, dtype):
        
        return x if torch.is_tensor(x) else torch.tensor(x, dtype = dtype, device = device)
        
    def surrogate_loss(self, old_log_probs, latent_states, advantages):
        
        _ , log_probs, mu, log_std = self.policy_network(latent_states)
        
        ratio = torch.exp(log_probs - old_log_probs)
        
        advantages = self.safe_tensor(advantages, dtype = torch.float32)
        
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
        
        surrogate = -(ratio * advantages).mean()
        
        std = torch.exp(log_std)
        
        dist = torch.distributions.Normal(mu, std)
        
        entropy = dist.entropy().sum(dim = -1).mean()
        
        total_loss = surrogate - entropy * self.entropy_coef
        
        return total_loss
        
        
    def compute_kl_divergence(self, latent_states):
        
        with torch.no_grad():
            
            _, _, mu, log_std = self.policy_network(latent_states)
            
        _, _, new_mu, new_log_std = self.policy_network(latent_states)
        
        old_std = torch.exp(log_std)
        new_std = torch.exp(new_log_std)
        
        KL_Div = (
            
            (log_std - new_log_std) +
            
            (((old_std).pow(2) + (mu - new_mu).pow(2)) / (2.0 * new_std.pow(2))) -0.5
        ) 
        
        return KL_Div.sum(dim = -1).mean()
    
    
    def conjugate_gradient(self, b, Av_func):
        
        x = torch.zeros_like(b)                  # we know nothing
        
        p = b.clone()                            # This is moving dir
        r = b.clone()                            # this is residual
        
        rs_old = torch.dot(r, r)                 # this is squared residual
        
        for _ in range(self.max_iter):
            
            Ap = Av_func(p)
            
            alpha = rs_old / (torch.dot(p, Ap) + 1e-8)
            
            x += alpha * p
            r -= alpha * Ap
            
            rs_new = torch.dot(r, r)
            
            if rs_new < self.tolerance:
            
                break
        
        p = r + (rs_new / rs_old) * p
        rs_old = rs_new
        
        return x
    
    
    def fisher_vector_product(self, vector, latent_states):
        
        # Compute Dist 1
        
        _, _, mu, log_std = self.policy_network(latent_states)
        
        std = torch.exp(log_std)
        
        dist = torch.distributions.Normal(mu, std)
        
        # Compute dist 2
        
        with torch.no_grad():
            
            _, _, old_mu, old_log_std = self.policy_network(latent_states)
            
        old_std = torch.exp(old_log_std)
        
        dist_2 = torch.distributions.Normal(old_mu, old_std)
        
        # Compute Kl Divergence
        
        kl = torch.distributions.kl_divergence(dist, dist_2).mean()
        
        # First order
        
        kl_grad = torch.autograd.grad(kl, self.policy_network.parameters(), create_graph = True)
        flat_kl_grad = torch.cat([g.view(-1) for g in kl_grad])
        
        kl_v = (flat_kl_grad * vector).sum()
        
        # Second order
        
        kl_grad_2 = torch.autograd.grad(kl_v, self.policy_network.parameters(), retain_graph = True)
        flat_kl_grad_2 = torch.cat([g.contiguous().view(-1) for g in kl_grad_2])
        
        return flat_kl_grad_2 + self.damping * vector
        
        
    def get_kl_loss(self, latent_states, old_log_probs, advantages):
        
        loss = self.surrogate_loss(old_log_probs, latent_states, advantages)
        
        kl_div = self.compute_kl_divergence(latent_states)
        
        return kl_div, loss
    
    def line_search(self, full_step, latent_states, old_log_probs, advantages):
        
        prev_params = torch.nn.utils.parameters_to_vector(self.policy_network.parameters())
        
        for step in [0.5 ** i for i in range(self.max_back_tracks)]:
            
            new_params = prev_params + step * full_step
            
            torch.nn.utils.vector_to_parameters(new_params, self.policy_network.parameters())
            
            kl, loss = self.get_kl_loss(latent_states, old_log_probs, advantages)
            
            if kl < self.max_kl and loss < 0 :
                
                return True, new_params
                
        torch.nn.utils.vector_to_parameters(prev_params, self.policy_network.parameters())
                
        return False, prev_params

# %% [markdown]
# ### **Setup**

# %%
# Hyper params

gamma = 0.997
gae_lam = 0.99
entropy_coef = 0.01
max_iter = 10
max_back_tracks = 20
tolerance = 1e-9
damping = 1e-2
max_kl = 0.01

# Setup

trpo_loss_function = TRPO_LOSS_FUNCTION(policy_network, value_network, value_optimizer, value_scheduler, entropy_coef, max_iter, tolerance, damping, max_back_tracks, max_kl)

# %% [markdown]
# ## **TRPO Agent Class**

# %%
class TRPO_AGENT:
    
    def __init__(self, policy_network, value_network, value_optimizer, value_scheduler, gamma, gae_lambda, trpo_loss_function = trpo_loss_function):

        self.policy = policy_network
        self.value = value_network
        
        self.value_opt = value_optimizer
        self.value_sch = value_scheduler
        
        self.gamma = gamma
        self.gae_lam = gae_lambda
        self.succeeded = 0
        
        self.loss_function = trpo_loss_function
        
    def update(self, replay_buffer, batch_size):
        
        states, actions, rewards, next_states, dones = replay_buffer.mix_batch(batch_size, ratio = 0.25)
        
        with torch.no_grad():
            
            value = self.value(states).squeeze(-1).detach()
            #value = value.cpu().numpy()
            
        
        # Compute last value
        
        with torch.no_grad():
            
            last_state = next_states[-1].unsqueeze(0).to(device)
            last_value = self.value(last_state).detach()

            last_value = last_value.item()
            
        advantages , returns = self.loss_function.compute_gae(rewards, last_value, value, dones, self.gamma, self.gae_lam)
        # Compute old log probs
        
        _, old_log_probs, _, _ = self.policy(states)
        
        # compute surrogate loss
        
        surrogate_loss = self.loss_function.surrogate_loss(old_log_probs, states, advantages)
        
        # compute surrogate gradient (b)
        
        grads = torch.autograd.grad(surrogate_loss, self.policy.parameters())
        flat_grads = torch.cat([g.view(-1) for g in grads])
        
        # Compute Fisher matrix
        
        Av_function = lambda v: self.loss_function.fisher_vector_product(v, states)
        step_direction = self.loss_function.conjugate_gradient(flat_grads, Av_function)
        
        # Compute full scale
        
        step_scale = (2 * self.loss_function.max_kl / (step_direction.dot(Av_function(step_direction)) + 1e-8 )) ** 0.5
        full_step = step_direction * step_scale
        
        # Line Search
         
        success, new_params = self.loss_function.line_search(full_step, states, old_log_probs, advantages)
            
        print(f'Success: {success}')
        
        if success:
            
            torch.nn.utils.vector_to_parameters(new_params, self.policy.parameters())
            self.succeeded += 1
            
        # Update Value Network
        
        for _ in range(10):
            
            v = self.value(states).squeeze(-1)
            
            returns = (returns - returns.mean()) / (returns.std() + 1e-8)
            
            loss = F.smooth_l1_loss(v, returns)
            
            self.value_opt.zero_grad()
            loss.backward()
            self.value_opt.step()
            self.value_sch.step()
            
        return loss.item(), self.succeeded

# %% [markdown]
# ### **Setup**

# %%
trpo_agent = TRPO_AGENT(policy_network, value_network, value_optimizer, value_scheduler, gamma, gae_lam)

# %% [markdown]
# ## **TRPO ROLLOUT**

# %%
def trpo_rollout(policy_network, env, max_steps, beta, world_buffer = world_buffer, encoder = encoder, ensemble = ensemble, trpo_loss_function = trpo_loss_function):
    
    state, _ = env.reset()
    
    for _ in range(max_steps):
        
        state = torch.tensor(state, dtype = torch.float32, device = device).unsqueeze(0)
        
        if state.shape[-1] != encoder.encoder[-1].out_features:
            
            state = encoder(state)
            
        action, _, _, _ = policy_network(state)
        
        action = action.squeeze(0).detach().cpu().numpy()
        
        next_state, reward, done, _, _ = env.step(action)
        
        next_state = next_state if torch.is_tensor(next_state) else torch.tensor(next_state, dtype = torch.float32, device= device)
        
        if next_state.dim() == 1:
            next_state = next_state.unsqueeze(0)
        
        if next_state.shape[-1] != encoder.encoder[-1].out_features:
            
            next_state = encoder(next_state)   
            
        action = action if torch.is_tensor(action) else torch.tensor(action, dtype = torch.float32, device = device).unsqueeze(0)
    
        intrinsic_reward = intrinsic_reward_signal(ensemble, state, action, reward, beta)
        
        dones = torch.tensor([done], dtype=torch.float32, device=device)
        
        world_buffer.add(state, action, intrinsic_reward, next_state, dones)
        
        if done:
            
            state, _ = env.reset()
            
        else:
            
            state = next_state
            
        return intrinsic_reward

# %%
def shaped_reward(reward , state):
    
    state = state.squeeze(0)
    
    is_falling = (state[2] < 0.8 or          # Height threshold
                 abs(state[3]) > 0.4 or      # Angular velocity X
                 abs(state[4]) > 0.4)        # Angular velocity Y
    
    if is_falling:
        
        recovery_bonus = 3.0 * (1 - abs(state[3]))
        survival_bonus = 0.5 * (0.8 - state[2])
        reward += recovery_bonus + survival_bonus
    
    else:
        
        reward += 0.05
        reward += 1.5 * state[1]
        reward += 0.3 * state[2] ** 2 # Height bonus quadritic
        reward += 1.5 * state[0] * (1 + state[2])   # Forward locomotion
        reward -= 0.1 * (state[3:6] ** 2).sum()  # Angular penalty
        reward -= 0.1 * (state[3] ** 2 + state[4] ** 2)
        
    return reward / 10.0

# %% [markdown]
# ## **Training**

# %%
def get_beta(episode, warmup=600, decay_start= 900, min_beta=0.01):
    if episode < warmup:
        return 1.0  # Pure curiosity at start
    elif episode < decay_start:
        return 0.5  # Mix of curiosity + reward
    else:
        return max(0.1 * (0.99 ** (episode - decay_start)), min_beta)

# %%
def training_block(
    max_episodes,
    update_every,
    roll_steps,
    steps,
    warm_up,
    batch_size=batch_size,
    env=env,
    trpo_agent=trpo_agent,
    world_buffer=world_buffer,
    encoder=encoder,
    world_loss_function=world_loss_function,
    value_network = value_network,
    policy_network = policy_network
):
    episode_reward = []
    max_reward = -np.inf

    for episode in range(max_episodes):
        state, _ = env.reset()
        ep_reward = 0.0
        ep_intrinsic = 0.0

        # ----------- STEP PHASE (interact with env) ------------
        for _ in range(steps):
            state = torch.tensor(state, dtype=torch.float32, device=device)
            
            if state.dim() == 1:
                state = state.unsqueeze(0)

            if state.shape[-1] != encoder.encoder[-1].out_features:
                state = encoder(state)

            action, _, _, _ = policy_network(state)
            
            action = action.squeeze(0).detach().cpu().numpy()
            
            next_state, reward, done, _, _ = env.step(action)
            
            reward = shaped_reward(reward, state)

            with torch.no_grad():
                v = value_network(state).squeeze(-1)

            next_state = trpo_agent.loss_function.safe_tensor(next_state, dtype=torch.float32).unsqueeze(0)
            if next_state.shape[-1] != encoder.encoder[-1].out_features:
                next_state = encoder(next_state)

            # Store in roller buffer
            
            action = torch.tensor(action, dtype = torch.float32, device = device)
            reward = torch.tensor([reward], dtype = torch.float32, device = device)
            done = torch.tensor([done], dtype = torch.float32, device = device)
            
            world_buffer.add_rollout_data(state, action, reward, next_state, done, v)

            ep_reward += reward.item()
            
            if ep_reward > max_reward:
                
                max_reward = ep_reward

            if done:
                break

            state = next_state

        # ----------- UPDATE PHASE (only after warmup) ------------
        
        if episode > warm_up and len(world_buffer.roller_buffer) >= batch_size:
            episode_reward.append(ep_reward)

            # 1. Train World Model on trajectory rollouts
            
            for _ in range(10): 
                
                trajectories = world_buffer.sample_rollout(batch_size)
                
                world_loss = world_loss_function.compute_loss(trajectories)

            # 2. Rollout new imagined data using TRPO policy
            
            if episode % update_every == 0:
                
                #beta = get_beta(episode)
                
                intrinsic_reward = trpo_rollout(trpo_agent.policy, env, roll_steps, beta = 0.1)
                ep_intrinsic += intrinsic_reward.sum().item()
                
                print(f"Episode: {episode} | Intrinsic reward: {ep_intrinsic:.4f}")

            # 3. Update TRPO Agent with mixed batch
            
            if len(world_buffer.buffer) >= batch_size:
                
                loss, success = trpo_agent.update(world_buffer, batch_size)
            else:
                print(f"Skipping TRPO update at episode {episode} | Not enough samples in World Buffer...")


        else:
            print(f"Episode: {episode} | Reward: {ep_reward:.2f} | Max reward: {max_reward} | Warm-up phase...")
            world_loss = torch.tensor(0.0)  # Dummy value
            loss, success = 0.0, 0  # Dummy values

        # ----------- LOGGING PHASE ------------
        print(" - " * 30)
        print(f"Episode: {episode} | Reward: {ep_reward:.2f} | Max reward: {max_reward} "
              f"| Loss: {loss:.4f} | Success: {success}")
        print(f"World Loss: {world_loss:.4f}\n")

# %%
training_block(max_episodes = 3000,
               update_every = 2,
               roll_steps = 5,
               steps = 1024,
               warm_up = 30)
# Out:
# Episode: 0 | Reward: 21.80 | Max reward: 21.800170183181763 | Warm-up phase...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 0 | Reward: 21.80 | Max reward: 21.800170183181763 | Loss: 0.0000 | Success: 0
# World Loss: 0.0000
#
# Episode: 1 | Reward: 20.98 | Max reward: 21.800170183181763 | Warm-up phase...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 1 | Reward: 20.98 | Max reward: 21.800170183181763 | Loss: 0.0000 | Success: 0
# World Loss: 0.0000
#
# Episode: 2 | Reward: 23.01 | Max reward: 23.012564092874527 | Warm-up phase...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 2 | Reward: 23.01 | Max reward: 23.012564092874527 | Loss: 0.0000 | Success: 0
# World Loss: 0.0000
#
# Episode: 3 | Reward: 16.60 | Max reward: 23.012564092874527 | Warm-up phase...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 3 | Reward: 16.60 | Max reward: 23.012564092874527 | Loss: 0.0000 | Success: 0
# World Loss: 0.0000
#
# Episode: 4 | Reward: 14.21 | Max reward: 23.012564092874527 | Warm-up phase...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode:
| Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 42 | Reward: 15.64 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0903
#
# Skipping TRPO update at episode 43 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 43 | Reward: 15.85 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0930
#
# Episode: 44 | Intrinsic reward: 481.6996
# Skipping TRPO update at episode 44 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 44 | Reward: 22.67 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0783
#
# Skipping TRPO update at episode 45 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 45 | Reward: 14.75 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0943
#
# Episode: 46 | Intrinsic reward: 483.1329
# Skipping TRPO update at episode 46 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 46 | Reward: 20.16 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1010
#
# Skipping TRPO update at episode 47 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 47 | Reward: 15.88 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1673
#
# Episode: 48 | Intrinsic reward: 487.7924
# Skipping TRPO update at episode 48 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 48 | Reward: 20.39 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1318
#
# Skipping TRPO update at episode 49 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 49 | Reward: 16.83 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1051
#
# Episode: 50 | Intrinsic reward: 487.5597
# Skipping TRPO update at episode 50 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 50 | Reward: 23.04 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0689
#
# Skipping TRPO update at episode 51 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 51 | Reward: 23.54 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0601
#
# Episode: 52 | Intrinsic reward: 481.3562
# Skipping TRPO update at episode 52 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 52 | Reward: 13.28 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1336
#
# Skipping TRPO update at episode 53 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 53 | Reward: 18.26 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0839
#
# Episode: 54 | Intrinsic reward: 481.8719
# Skipping TRPO update at episode 54 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 54 | Reward: 13.82 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1037
#
# Skipping TRPO update at episode 55 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 55 | Reward: 16.09 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0907
#
# Episode: 56 | Intrinsic reward: 483.4980
# Skipping TRPO update at episode 56 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 56 | Reward: 14.15 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0597
#
# Skipping TRPO update at episode 57 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 57 | Reward: 16.79 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0983
#
# Episode: 58 | Intrinsic reward: 483.4932
# Skipping TRPO update at episode 58 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 58 | Reward: 15.34 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1101
#
# Skipping TRPO update at episode 59 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 59 | Reward: 13.29 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0605
#
# Episode: 60 | Intrinsic reward: 483.6146
# Skipping TRPO update at episode 60 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 60 | Reward: 21.53 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1218
#
# Skipping TRPO update at episode 61 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 61 | Reward: 17.40 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0962
#
# Episode: 62 | Intrinsic reward: 483.1600
# Skipping TRPO update at episode 62 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 62 | Reward: 16.39 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0916
#
# Skipping TRPO update at episode 63 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 63 | Reward: 14.24 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0778
#
# Episode: 64 | Intrinsic reward: 483.8083
# Skipping TRPO update at episode 64 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 64 | Reward: 18.04 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0915
#
# Skipping TRPO update at episode 65 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 65 | Reward: 14.60 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1154
#
# Episode: 66 | Intrinsic reward: 483.9415
# Skipping TRPO update at episode 66 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 66 | Reward: 18.97 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0981
#
# Skipping TRPO update at episode 67 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 67 | Reward: 14.64 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1107
#
# Episode: 68 | Intrinsic reward: 480.9565
# Skipping TRPO update at episode 68 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 68 | Reward: 28.69 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0798
#
# Skipping TRPO update at episode 69 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 69 | Reward: 14.10 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0990
#
# Episode: 70 | Intrinsic reward: 484.1856
# Skipping TRPO update at episode 70 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 70 | Reward: 15.98 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1022
#
# Skipping TRPO update at episode 71 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 71 | Reward: 26.47 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0867
#
# Episode: 72 | Intrinsic reward: 484.3458
# Skipping TRPO update at episode 72 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 72 | Reward: 15.92 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0903
#
# Skipping TRPO update at episode 73 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 73 | Reward: 21.88 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1039
#
# Episode: 74 | Intrinsic reward: 481.0524
# Skipping TRPO update at episode 74 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 74 | Reward: 19.86 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1032
#
# Skipping TRPO update at episode 75 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 75 | Reward: 14.38 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1405
#
# Episode: 76 | Intrinsic reward: 483.8710
# Skipping TRPO update at episode 76 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 76 | Reward: 14.26 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0623
#
# Skipping TRPO update at episode 77 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 77 | Reward: 19.49 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1166
#
# Episode: 78 | Intrinsic reward: 483.8083
# Skipping TRPO update at episode 78 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 78 | Reward: 14.20 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0730
#
# Skipping TRPO update at episode 79 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 79 | Reward: 20.88 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1547
#
# Episode: 80 | Intrinsic reward: 482.9034
# Skipping TRPO update at episode 80 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 80 | Reward: 23.07 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0886
#
# Skipping TRPO update at episode 81 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 81 | Reward: 15.09 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0497
#
# Episode: 82 | Intrinsic reward: 484.6096
# Skipping TRPO update at episode 82 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 82 | Reward: 20.92 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0612
#
# Skipping TRPO update at episode 83 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 83 | Reward: 16.85 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0646
#
# Episode: 84 | Intrinsic reward: 477.2405
# Skipping TRPO update at episode 84 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 84 | Reward: 21.28 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1101
#
# Skipping TRPO update at episode 85 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 85 | Reward: 15.86 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0832
#
# Episode: 86 | Intrinsic reward: 486.4995
# Skipping TRPO update at episode 86 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 86 | Reward: 13.41 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0671
#
# Skipping TRPO update at episode 87 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 87 | Reward: 16.11 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0963
#
# Episode: 88 | Intrinsic reward: 484.7941
# Skipping TRPO update at episode 88 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 88 | Reward: 14.17 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1237
#
# Skipping TRPO update at episode 89 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 89 | Reward: 16.55 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0872
#
# Episode: 90 | Intrinsic reward: 483.5032
# Skipping TRPO update at episode 90 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 90 | Reward: 13.37 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1000
#
# Skipping TRPO update at episode 91 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 91 | Reward: 18.71 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0886
#
# Episode: 92 | Intrinsic reward: 481.6543
# Skipping TRPO update at episode 92 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 92 | Reward: 15.86 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0944
#
# Skipping TRPO update at episode 93 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 93 | Reward: 19.02 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0847
#
# Episode: 94 | Intrinsic reward: 483.5338
# Skipping TRPO update at episode 94 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 94 | Reward: 20.93 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1065
#
# Skipping TRPO update at episode 95 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 95 | Reward: 16.86 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0841
#
# Episode: 96 | Intrinsic reward: 483.3000
# Skipping TRPO update at episode 96 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 96 | Reward: 24.88 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0417
#
# Skipping TRPO update at episode 97 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 97 | Reward: 13.28 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1007
#
# Episode: 98 | Intrinsic reward: 483.1308
# Skipping TRPO update at episode 98 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 98 | Reward: 28.69 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1012
#
# Skipping TRPO update at episode 99 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 99 | Reward: 13.34 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0922
#
# Episode: 100 | Intrinsic reward: 483.3778
# Skipping TRPO update at episode 100 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 100 | Reward: 13.31 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0936
#
# Skipping TRPO update at episode 101 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 101 | Reward: 14.56 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0834
#
# Episode: 102 | Intrinsic reward: 482.5758
# Skipping TRPO update at episode 102 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 102 | Reward: 14.36 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1252
#
# Skipping TRPO update at episode 103 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 103 | Reward: 17.35 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1023
#
# Episode: 104 | Intrinsic reward: 482.2033
# Skipping TRPO update at episode 104 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 104 | Reward: 21.24 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1101
#
# Skipping TRPO update at episode 105 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 105 | Reward: 20.37 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0811
#
# Episode: 106 | Intrinsic reward: 482.4035
# Skipping TRPO update at episode 106 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 106 | Reward: 19.06 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1025
#
# Skipping TRPO update at episode 107 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 107 | Reward: 21.43 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1100
#
# Episode: 108 | Intrinsic reward: 481.1235
# Skipping TRPO update at episode 108 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 108 | Reward: 13.37 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1082
#
# Skipping TRPO update at episode 109 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 109 | Reward: 20.54 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0959
#
# Episode: 110 | Intrinsic reward: 481.6056
# Skipping TRPO update at episode 110 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 110 | Reward: 16.50 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0619
#
# Skipping TRPO update at episode 111 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 111 | Reward: 13.39 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1213
#
# Episode: 112 | Intrinsic reward: 482.6761
# Skipping TRPO update at episode 112 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 112 | Reward: 29.05 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0764
#
# Skipping TRPO update at episode 113 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 113 | Reward: 17.29 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0828
#
# Episode: 114 | Intrinsic reward: 482.0568
# Skipping TRPO update at episode 114 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 114 | Reward: 13.38 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0977
#
# Skipping TRPO update at episode 115 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 115 | Reward: 15.78 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0569
#
# Episode: 116 | Intrinsic reward: 481.4364
# Skipping TRPO update at episode 116 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 116 | Reward: 19.46 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0748
#
# Skipping TRPO update at episode 117 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 117 | Reward: 15.20 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1187
#
# Episode: 118 | Intrinsic reward: 482.1704
# Skipping TRPO update at episode 118 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 118 | Reward: 22.42 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0972
#
# Skipping TRPO update at episode 119 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 119 | Reward: 30.02 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0919
#
# Episode: 120 | Intrinsic reward: 480.0124
# Skipping TRPO update at episode 120 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 120 | Reward: 15.04 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1365
#
# Skipping TRPO update at episode 121 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 121 | Reward: 14.02 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1076
#
# Episode: 122 | Intrinsic reward: 481.7444
# Skipping TRPO update at episode 122 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 122 | Reward: 12.54 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0990
#
# Skipping TRPO update at episode 123 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 123 | Reward: 26.61 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0738
#
# Episode: 124 | Intrinsic reward: 480.9998
# Skipping TRPO update at episode 124 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 124 | Reward: 15.05 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0795
#
# Skipping TRPO update at episode 125 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 125 | Reward: 35.35 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0712
#
# Episode: 126 | Intrinsic reward: 482.2025
# Skipping TRPO update at episode 126 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 126 | Reward: 20.76 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0844
#
# Skipping TRPO update at episode 127 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 127 | Reward: 14.26 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1204
#
# Episode: 128 | Intrinsic reward: 483.6315
# Skipping TRPO update at episode 128 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 128 | Reward: 27.56 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1464
#
# Skipping TRPO update at episode 129 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 129 | Reward: 13.37 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0551
#
# Episode: 130 | Intrinsic reward: 481.8344
# Skipping TRPO update at episode 130 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 130 | Reward: 13.32 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1127
#
# Skipping TRPO update at episode 131 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 131 | Reward: 13.31 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0610
#
# Episode: 132 | Intrinsic reward: 479.5067
# Skipping TRPO update at episode 132 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 132 | Reward: 15.70 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.0676
#
# Skipping TRPO update at episode 133 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 133 | Reward: 14.07 | Max reward: 35.52414005994797 | Loss: 0.0000 | Success: 0
# World Loss: 0.1014
#
# Episode: 134 | Intrinsic reward: 482.2073
# Skipping TRPO update at episode 134 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 134 | Reward: 37.73 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.0859
#
# Skipping TRPO update at episode 135 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 135 | Reward: 13.50 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.1303
#
# Episode: 136 | Intrinsic reward: 478.8788
# Skipping TRPO update at episode 136 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 136 | Reward: 14.25 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.0759
#
# Skipping TRPO update at episode 137 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 137 | Reward: 13.41 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.1125
#
# Episode: 138 | Intrinsic reward: 484.7440
# Skipping TRPO update at episode 138 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 138 | Reward: 25.76 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.1208
#
# Skipping TRPO update at episode 139 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 139 | Reward: 25.98 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.1037
#
# Episode: 140 | Intrinsic reward: 483.1021
# Skipping TRPO update at episode 140 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 140 | Reward: 31.81 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.0843
#
# Skipping TRPO update at episode 141 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 141 | Reward: 13.86 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.1063
#
# Episode: 142 | Intrinsic reward: 480.2419
# Skipping TRPO update at episode 142 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 142 | Reward: 14.16 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.0589
#
# Skipping TRPO update at episode 143 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 143 | Reward: 15.09 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.1134
#
# Episode: 144 | Intrinsic reward: 483.1388
# Skipping TRPO update at episode 144 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 144 | Reward: 25.22 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.0583
#
# Skipping TRPO update at episode 145 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 145 | Reward: 14.20 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.1098
#
# Episode: 146 | Intrinsic reward: 483.4974
# Skipping TRPO update at episode 146 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 146 | Reward: 14.04 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.1386
#
# Skipping TRPO update at episode 147 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 147 | Reward: 18.41 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.0931
#
# Episode: 148 | Intrinsic reward: 484.0840
# Skipping TRPO update at episode 148 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 148 | Reward: 27.42 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.0707
#
# Skipping TRPO update at episode 149 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 149 | Reward: 28.58 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.1080
#
# Episode: 150 | Intrinsic reward: 485.4914
# Skipping TRPO update at episode 150 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 150 | Reward: 16.75 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.0637
#
# Skipping TRPO update at episode 151 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 151 | Reward: 16.82 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.1287
#
# Episode: 152 | Intrinsic reward: 482.4695
# Skipping TRPO update at episode 152 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 152 | Reward: 21.04 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.0618
#
# Skipping TRPO update at episode 153 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 153 | Reward: 22.55 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.0604
#
# Episode: 154 | Intrinsic reward: 484.8518
# Skipping TRPO update at episode 154 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 154 | Reward: 24.01 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.1092
#
# Skipping TRPO update at episode 155 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 155 | Reward: 19.74 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.0927
#
# Episode: 156 | Intrinsic reward: 483.8177
# Skipping TRPO update at episode 156 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 156 | Reward: 17.95 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.0638
#
# Skipping TRPO update at episode 157 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 157 | Reward: 22.43 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.1045
#
# Episode: 158 | Intrinsic reward: 482.6772
# Skipping TRPO update at episode 158 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 158 | Reward: 14.21 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.0815
#
# Skipping TRPO update at episode 159 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 159 | Reward: 16.78 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.0743
#
# Episode: 160 | Intrinsic reward: 487.3734
# Skipping TRPO update at episode 160 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 160 | Reward: 14.14 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.1021
#
# Skipping TRPO update at episode 161 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 161 | Reward: 25.36 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.0722
#
# Episode: 162 | Intrinsic reward: 481.4983
# Skipping TRPO update at episode 162 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 162 | Reward: 16.66 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.1266
#
# Skipping TRPO update at episode 163 | Not enough samples in World Buffer...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 163 | Reward: 16.14 | Max reward: 37.72572836279869 | Loss: 0.0000 | Success: 0
# World Loss: 0.0882
#
# Episode: 164 | Intrinsic reward: 481.4274
# ...
# Episode: 2933 | Reward: 36.75 | Max reward: 123.80749894678593 | Loss: 0.1924 | Success: 2392
# World Loss: 0.1148
#
# Episode: 2934 | Intrinsic reward: 480.9478
# Success: True
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 2934 | Reward: 40.59 | Max reward: 123.80749894678593 | Loss: 0.1881 | Success: 2393
# World Loss: 0.0666
#
# Success: True
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 2935 | Reward: 29.26 | Max reward: 123.80749894678593 | Loss: 0.1998 | Success: 2394
# World Loss: 0.1145
#
# Episode: 2936 | Intrinsic reward: 482.4769
# Success: True
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Episode: 